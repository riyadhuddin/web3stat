# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %%
data = pd.read_csv('nft_sales.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4000\1749638866.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('nft_sales.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  collection_slug  collection_name  \
# 0           0          rarible          Rarible
# 1           1  rarebit-bunnies  Rarebit Bunnies
# 2           2          rarible          Rarible
# 3           3          rarible          Rarible
# 4           4   chainguardians   ChainGuardians
#
#                                   collection_url  asset_id  \
# 0          https://opensea.io/collection/rarible  18214580
# 1  https://opensea.io/collection/rarebit-bunnies  18276844
# 2          https://opensea.io/collection/rarible  16911700
# 3          https://opensea.io/collection/rarible  16986936
# 4   https://opensea.io/collection/chainguardians  13382164
#
#                      asset_name  \
# 0           Daft Punk Never Die
# 1  Rarebit #164 - Wax Off Bunny
# 2                    Meditation
# 3                        I´m OG
# 4               Celia B100 #105
#
#                                    asset_description  \
# 0  Piece of art, Daft Punk, always in our hears.\...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108147 entries, 0 to 108146
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              108147 non-null  int64
#  1   collection_slug         108147 non-null  object
#  2   collection_name         108147 non-null  object
#  3   collection_url          108147 non-null  object
#  4   asset_id                108147 non-null  int64
#  5   asset_name              107776 non-null  object
#  6   asset_description       101491 non-null  object
#  7   asset_contract_date     108147 non-null  object
#  8   asset_url               108147 non-null  object
#  9   asset_img_url           107986 non-null  object
#  10  event_id                108147 non-null  int64
#  11  event_time              108147 non-null  object
#  12  event_auction_type      70980 non-null   object
#  13  event_contract_address  108132 non-null  object
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0      asset_id      event_id  event_total_price
# count  108147.000000  1.081470e+05  1.081470e+05       1.081430e+05
# mean    46980.453781  1.632008e+07  7.926374e+07       2.554018e+02
# std     30403.159967  4.079440e+06  1.113193e+06       1.475289e+04
# min         0.000000  9.210000e+02  7.740268e+07       0.000000e+00
# 25%     19405.500000  1.696152e+07  7.832259e+07       3.300000e-02
# 50%     46442.000000  1.772870e+07  7.930960e+07       1.000000e-01
# 75%     73478.500000  1.797027e+07  8.038010e+07       5.000000e-01
# max    100515.000000  1.830540e+07  8.104380e+07       2.890620e+06

# %%
# calculate the total number of null values in each column
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# collection_slug               0
# collection_name               0
# collection_url                0
# asset_id                      0
# asset_name                  371
# asset_description          6656
# asset_contract_date           0
# asset_url                     0
# asset_img_url               161
# event_id                      0
# event_time                    0
# event_auction_type        37167
# event_contract_address       15
# event_quantity                0
# event_payment_symbol         15
# event_total_price             4
# dtype: int64

# %%
# summerise event_total_price 
data['event_total_price'].sum()
# Out:
# 27619914.359243393

# %%
# event_payment_symbol value counts
data['event_payment_symbol'].value_counts()
# Out:
# ETH       100024
# WETH        6385
# MANA         455
# DAI          273
# SAND         162
# USDC         140
# UNI          111
# PGU           98
# RARI          76
# ELAND         73
# GALA          39
# REVV          39
# ABST          36
# MEME          34
# BONDLY        27
# DENA          18
# ECAT          18
# ARCONA        17
# SMTS          12
# ROPE          10
# TRSH           8
# ENJ            7
# WHALE          6
# KLTR           5
# ART            5
# MGDv2          5
# CUBE           4
# SKULL          4
# ATRI           4
# ASLT           4
# MORK           3
# WCK            3
# DHC            3
# PPDEX          3
# HUE            2
# SURF           2
# GR1M           2
# GUSD           2
# BAT            1
# KAP            1
# MBC            1
# WIPC           1
# FTM            1
# CRED           1
# 0xBTC          1
# VI             1
# FUD            1
# YUMI           1
# NUGS           1
# BONES          1
# NDR            1
# ...
